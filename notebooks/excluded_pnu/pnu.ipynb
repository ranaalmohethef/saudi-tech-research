# %% [markdown]
# # Task 1: Data Extraction
#
# ## Objective
# This notebook extracts raw research publication data from source files and APIs without applying any transformation or cleaning steps.

# %% [markdown]
# ## Import Required Libraries
#
# This section imports the Python libraries needed for reading source files, handling data, and connecting to APIs.

# %%
# Import pandas for reading and analyzing tabular data
import pandas as pd

# Import requests for connecting to external APIs
import requests

# Import json for handling JSON data files
import json

# Import os for working with file paths and directories
import os

# %% [markdown]
# ## Define Raw Data Path
#
# This section defines the location of the raw source files that will be used during the extraction process.

# %%
# Define the location of raw source files
raw_path = "../data/raw/"

# %% [markdown]
# ## Check Raw Data Files
#
# This section checks that the raw source files are available before loading the data.

# %%
# Get the list of files available in the raw folder
raw_files = os.listdir(raw_path)

# Display available raw files
raw_files
# Out:
# ['.gitkeep', 'PNU_2023_raw.xlsx', 'PNU_2024_raw.xlsx', 'PNU_2025_raw.xlsx']

# %% [markdown]
# ## Load All PNU Raw Files
#
# This section loads all available PNU raw files from different years without applying any transformations.

# %%
# Load the original PNU 2023 raw dataset

pnu_2023 = pd.read_excel(
    "../data/raw/PNU_2023_raw.xlsx"
)

# Display the first rows of the raw data
pnu_2023.head()
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0               NaN        NaN        NaN        NaN              NaN
# 1               NaN        NaN        NaN        NaN              NaN
# 2               NaN        NaN        NaN        NaN              NaN
# 3               NaN        NaN        NaN        NaN              NaN
# 4  Publication Year      Month   Category    college  Research field
#
#   Unnamed: 5    Unnamed: 6
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4      Title  Source Title

# %%
# Load the original PNU 2024 raw dataset

pnu_2024 = pd.read_excel(
    "../data/raw/PNU_2024_raw.xlsx"
)

# Display the first rows of the raw data
pnu_2024.head()
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0               NaN        NaN        NaN        NaN              NaN
# 1               NaN        NaN        NaN        NaN              NaN
# 2               NaN        NaN        NaN        NaN              NaN
# 3               NaN        NaN        NaN        NaN              NaN
# 4  Publication Year      Month   Category    college  Research field
#
#   Unnamed: 5    Unnamed: 6
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4      Title  Source Title

# %%
# Load the original PNU 2025 raw dataset

pnu_2025 = pd.read_excel(
    "../data/raw/PNU_2025_raw.xlsx"
)

# Display the first rows of the raw data
pnu_2025.head()
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3       Unnamed: 4  \
# 0               NaN        NaN        NaN        NaN              NaN
# 1               NaN        NaN        NaN        NaN              NaN
# 2               NaN        NaN        NaN        NaN              NaN
# 3               NaN        NaN        NaN        NaN              NaN
# 4  Publication Year      Month   Category    college  Research field
#
#   Unnamed: 5    Unnamed: 6
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4      Title  Source Title

# %% [markdown]
# ## Inspect Raw Data Columns
#
# This section displays the column names available in the raw PNU datasets to understand the structure of the source files.

# %%
# Display column names for PNU 2023 raw data

pnu_2023.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='str')

# %%
# Display column names for PNU 2024 raw data

pnu_2024.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='str')

# %%
# Display column names for PNU 2025 raw data

pnu_2025.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='str')

# %% [markdown]
# ## Preview Raw File Structure
#
# This section previews the raw file structure to identify the correct header row before loading the dataset.

# %%
# Display the first rows of the raw PNU 2023 file without assuming a header

pd.read_excel(
    "../data/raw/PNU_2023_raw.xlsx",
    header=None
).head(10)
# Out:
#                   0       1         2  \
# 0               NaN     NaN       NaN
# 1               NaN     NaN       NaN
# 2               NaN     NaN       NaN
# 3               NaN     NaN       NaN
# 4               NaN     NaN       NaN
# 5  Publication Year   Month  Category
# 6              2023   March    scopus
# 7              2023   April    SCOPUS
# 8              2023   April    SCOPUS
# 9              2023  August    scopus
#
#                                                    3                4  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
# 5                                            college  Research field
# ...

# %%
# Display the first rows of the raw PNU 2024 file without assuming a header

pd.read_excel(
    "../data/raw/PNU_2024_raw.xlsx",
    header=None
).head(10)
# Out:
#                   0        1         2  \
# 0               NaN      NaN       NaN
# 1               NaN      NaN       NaN
# 2               NaN      NaN       NaN
# 3               NaN      NaN       NaN
# 4               NaN      NaN       NaN
# 5  Publication Year    Month  Category
# 6              2024  January    Scopus
# 7              2024  January    Scopus
# 8              2024  January    Scopus
# 9              2024  January       WOS
#
#                                                  3                         4  \
# 0                                              NaN                       NaN
# 1                                              NaN                       NaN
# 2                                              NaN                       NaN
# 3                                              NaN                       NaN
# 4                                              NaN                       NaN
# ...

# %%
# Display the first rows of the raw PNU 2025 file without assuming a header

pd.read_excel(
    "../data/raw/PNU_2025_raw.xlsx",
    header=None
).head(10)
# Out:
#                   0        1         2  \
# 0               NaN      NaN       NaN
# 1               NaN      NaN       NaN
# 2               NaN      NaN       NaN
# 3               NaN      NaN       NaN
# 4               NaN      NaN       NaN
# 5  Publication Year    Month  Category
# 6              2025  January       WOS
# 7              2025  January       WOS
# 8              2025  January       WOS
# 9              2025  January       WOS
#
#                                             3                         4  \
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2                                         NaN                       NaN
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# 5                                     college           Research field
# ...

# %% [markdown]
# ## Load Raw Data Using the Identified Header Row
#
# After inspecting the raw file structure, the correct header row was identified and used to load the datasets.

# %%
# Reload the raw file using the identified header row after inspecting the source structure

pnu_2023_header_check = pd.read_excel(
    "../data/raw/PNU_2023_raw.xlsx",
    header=5
)

# Display the detected column names
pnu_2023_header_check.columns
# Out:
# Index(['Publication Year', 'Month', 'Category', 'college', 'Research field ',
#        'Title', 'Source Title'],
#       dtype='str')

# %%
# Reload the raw file using the identified header row after inspecting the source structure

pnu_2024_header_check = pd.read_excel(
    "../data/raw/PNU_2024_raw.xlsx",
    header=5
)

# Display the detected column names
pnu_2024_header_check.columns
# Out:
# Index(['Publication Year', 'Month', 'Category', 'college', 'Research field ',
#        'Title', 'Source Title'],
#       dtype='str')

# %%
# Reload the raw file using the identified header row after inspecting the source structure

pnu_2025_header_check = pd.read_excel(
    "../data/raw/PNU_2025_raw.xlsx",
    header=5
)

# Display the detected column names
pnu_2025_header_check.columns
# Out:
# Index(['Publication Year', 'Month', 'Category', 'college', 'Research field ',
#        'Title', 'Source Title'],
#       dtype='str')

# %% [markdown]
# ## Extract Raw PNU Data
#
# This section extracts the raw PNU datasets using the identified header row while keeping the original source files unchanged.

# %%
# Extract PNU 2023 raw data using the identified header row

pnu_2023 = pd.read_excel(
    "../data/raw/PNU_2023_raw.xlsx",
    header=5
)

# Display first rows of extracted data
pnu_2023.head()
# Out:
#    Publication Year     Month Category  \
# 0              2023     March   scopus
# 1              2023     April   SCOPUS
# 2              2023     April   SCOPUS
# 3              2023    August   scopus
# 4              2023  December      Wos
#
#                                              college Research field   \
# 0  Arabic Language Teaching Institute for Non-Ara...   Humanitarian
# 1  Arabic Language Teaching Institute for Non-Ara...   Humanitarian
# 2  Arabic Language Teaching Institute for Non-Ara...   Humanitarian
# 3  Arabic Language Teaching Institute for Non-Ara...   Humanitarian
# 4  Arabic Language Teaching Institute for Non-Ara...   Humanitarian
#
#                                                Title  \
# 0  Sexual workplace violence in the health sector...
# 1  Spatial Analysis of Accessibility to Urban Gre...
# 2  Association of CCND1 (c.723G > A, rs9344) vari...
# 3  Neuroprotective Effect of Barbaloin on Strepto...
# ...

# %%
# Extract PNU 2024 raw data using the identified header row

pnu_2024 = pd.read_excel(
    "../data/raw/PNU_2024_raw.xlsx",
    header=5
)

# Display first rows of extracted data
pnu_2024.head()
# Out:
#    Publication Year    Month Category  \
# 0              2024  January   Scopus
# 1              2024  January   Scopus
# 2              2024  January   Scopus
# 3              2024  January      WOS
# 4              2024  January   Scopus
#
#                                            college           Research field   \
# 0              Foundation Year for Health Colleges  Health-related / Medical
# 1              Foundation Year for Health Colleges  Health-related / Medical
# 2  College of Sports Science and Physical Activity             Humanitarian
# 3  College of Sports Science and Physical Activity             Humanitarian
# 4                       College of Arts and Design             Humanitarian
#
#                                                Title  \
# 0  Immunopathology of herpes simplex virus-associ...
# 1  Synthesis, biological evaluation and molecular...
# 2  The Multifunctional TRPC6 Protein: Significanc...
# 3  Anti-inflammatory effects of bay laurel (Lauru...
# ...

# %%
# Extract PNU 2025 raw data using the identified header row

pnu_2025 = pd.read_excel(
    "../data/raw/PNU_2025_raw.xlsx",
    header=5
)

# Display first rows of extracted data
pnu_2025.head()
# Out:
#    Publication Year    Month Category  \
# 0              2025  January      WOS
# 1              2025  January      WOS
# 2              2025  January      WOS
# 3              2025  January      WOS
# 4              2025  January      WOS
#
#                                       college           Research field   \
# 0  College of Education and Human Development             Humanitarian
# 1  College of Education and Human Development             Humanitarian
# 2  College of Education and Human Development             Humanitarian
# 3                          College of Nursing  Health-related / Medical
# 4                          College of Nursing  Health-related / Medical
#
#                                                Title  \
# 0  Sustainable Entrepreneurial Intention Among Un...
# 1  The Effects of Using Augmented Reality on Phon...
# 2  The enigmatic role of SIRT2 in the cardiovascu...
# 3  Assessing neonatal nurses: transitioning prete...
# ...

# %% [markdown]
# ## Save Extracted Raw Data
#
# This section saves the extracted datasets for further processing while keeping the original raw files unchanged.

# %%
# Save extracted PNU datasets as CSV files for the next pipeline stage

pnu_2023.to_csv("../data/interim/PNU_2023_extracted.csv", index=False)
pnu_2024.to_csv("../data/interim/PNU_2024_extracted.csv", index=False)
pnu_2025.to_csv("../data/interim/PNU_2025_extracted.csv", index=False)

# %% [markdown]
# ## Verify Extracted Files
#
# This section verifies that the extracted files were created successfully and are ready for the next processing stage.

# %%
# Check extracted files in the interim folder

os.listdir("../data/interim/")
# Out:
# ['.gitkeep',
#  'PNU_2023_extracted.csv',
#  'PNU_2024_extracted.csv',
#  'PNU_2025_extracted.csv']

# %% [markdown]
# ## Source Definition
#
# This section documents the source information used in the extraction process.

# %% [markdown]
# ### Source Information
#
# - Source Name: Princess Nourah bint Abdulrahman University (PNU)
# - Source Type: Excel files
# - Data Period: 2023 - 2025
# - File Format: XLSX
# - Storage Location: data/raw/
# - Extraction Method: Reading source files using Python pandas

# %% [markdown]
# ## Extraction Output Check
#
# This section verifies that the extracted files were created successfully.

# %%
# Verify extracted files available for the next pipeline stage

extracted_files = os.listdir("../data/interim/")

extracted_files
# Out:
# ['.gitkeep',
#  'PNU_2023_extracted.csv',
#  'PNU_2024_extracted.csv',
#  'PNU_2025_extracted.csv']
